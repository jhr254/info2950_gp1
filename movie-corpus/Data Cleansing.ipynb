# %%
import pandas as pd
from pathlib import Path
import json
import csv

# %%
speakers_df = pd.read_csv("speakers.csv")

# %%
speakers_df_cleaned = speakers_df[(speakers_df != '?').all(axis=1)]
display(speakers_df_cleaned)
# Out:
#        _key meta/character_name meta/movie_idx             meta/movie_name  \
# 0        u0              BIANCA             m0  10 things i hate about you
# 1        u2             CAMERON             m0  10 things i hate about you
# 3        u4                JOEY             m0  10 things i hate about you
# 4        u5                 KAT             m0  10 things i hate about you
# 5       u11              WALTER             m0  10 things i hate about you
# ...     ...                 ...            ...                         ...
# 8997  u9001               YORGI           m613                         xxx
# 9018  u9015           ELIZABETH           m615          young frankenstein
# 9019  u9019                IGOR           m615          young frankenstein
# 9021  u9022     MEDICAL STUDENT           m615          young frankenstein
# 9023  u9020                INGA           m615          young frankenstein
#
#      meta/gender meta/credit_pos
# 0              f               4
# 1              m               3
# 3              m               6
# 4              f               2
# 5              m               9
# ...          ...             ...
# 8997           m               3
# 9018           f              25
# 9019           m               3
# 9021           m               9
# 9023           f               5
#
# [2679 rows x 6 columns]

# %%
speakers_df_cleaned.dropna()
# Out:
#        _key meta/character_name meta/movie_idx             meta/movie_name  \
# 0        u0              BIANCA             m0  10 things i hate about you
# 1        u2             CAMERON             m0  10 things i hate about you
# 3        u4                JOEY             m0  10 things i hate about you
# 4        u5                 KAT             m0  10 things i hate about you
# 5       u11              WALTER             m0  10 things i hate about you
# ...     ...                 ...            ...                         ...
# 8997  u9001               YORGI           m613                         xxx
# 9018  u9015           ELIZABETH           m615          young frankenstein
# 9019  u9019                IGOR           m615          young frankenstein
# 9021  u9022     MEDICAL STUDENT           m615          young frankenstein
# 9023  u9020                INGA           m615          young frankenstein
#
#      meta/gender meta/credit_pos
# 0              f               4
# 1              m               3
# 3              m               6
# 4              f               2
# 5              m               9
# ...          ...             ...
# 8997           m               3
# 9018           f              25
# 9019           m               3
# 9021           m               9
# 9023           f               5
#
# [2679 rows x 6 columns]

# %%
conversations_df = pd.read_csv("conversations.csv")
display(conversations_df)
# Out:
#           _key meta/movie_idx             meta/movie_name meta/release_year  \
# 0        L1044             m0  10 things i hate about you              1999
# 1         L984             m0  10 things i hate about you              1999
# 2         L924             m0  10 things i hate about you              1999
# 3         L870             m0  10 things i hate about you              1999
# 4         L866             m0  10 things i hate about you              1999
# ...        ...            ...                         ...               ...
# 83092  L666324           m616                   zulu dawn              1979
# 83093  L666262           m616                   zulu dawn              1979
# 83094  L666520           m616                   zulu dawn              1979
# 83095  L666369           m616                   zulu dawn              1979
# 83096  L666256           m616                   zulu dawn              1979
#
#        meta/rating  meta/votes  \
# 0              6.9       62847
# 1              6.9       62847
# 2              6.9       62847
# 3              6.9       62847
# 4              6.9       62847
# ...            ...         ...
# 83092          6.4        1911
# 83093          6.4        1911
# 83094          6.4        1911
# 83095          6.4        1911
# 83096          6.4        1911
#
#                                               meta/genre
# 0                                  ['comedy', 'romance']
# 1                                  ['comedy', 'romance']
# 2                                  ['comedy', 'romance']
# 3                                  ['comedy', 'romance']
# 4                                  ['comedy', 'romance']
# ...                                                  ...
# 83092  ['action', 'adventure', 'drama', 'history', 'w...
# 83093  ['action', 'adventure', 'drama', 'history', 'w...
# 83094  ['action', 'adventure', 'drama', 'history', 'w...
# 83095  ['action', 'adventure', 'drama', 'history', 'w...
# 83096  ['action', 'adventure', 'drama', 'history', 'w...
#
# [83097 rows x 7 columns]

# %%
conversations_df.dropna()
# Out:
#           _key meta/movie_idx             meta/movie_name meta/release_year  \
# 0        L1044             m0  10 things i hate about you              1999
# 1         L984             m0  10 things i hate about you              1999
# 2         L924             m0  10 things i hate about you              1999
# 3         L870             m0  10 things i hate about you              1999
# 4         L866             m0  10 things i hate about you              1999
# ...        ...            ...                         ...               ...
# 83092  L666324           m616                   zulu dawn              1979
# 83093  L666262           m616                   zulu dawn              1979
# 83094  L666520           m616                   zulu dawn              1979
# 83095  L666369           m616                   zulu dawn              1979
# 83096  L666256           m616                   zulu dawn              1979
#
#        meta/rating  meta/votes  \
# 0              6.9       62847
# 1              6.9       62847
# 2              6.9       62847
# 3              6.9       62847
# 4              6.9       62847
# ...            ...         ...
# 83092          6.4        1911
# 83093          6.4        1911
# 83094          6.4        1911
# 83095          6.4        1911
# 83096          6.4        1911
#
#                                               meta/genre
# 0                                  ['comedy', 'romance']
# 1                                  ['comedy', 'romance']
# 2                                  ['comedy', 'romance']
# 3                                  ['comedy', 'romance']
# 4                                  ['comedy', 'romance']
# ...                                                  ...
# 83092  ['action', 'adventure', 'drama', 'history', 'w...
# 83093  ['action', 'adventure', 'drama', 'history', 'w...
# 83094  ['action', 'adventure', 'drama', 'history', 'w...
# 83095  ['action', 'adventure', 'drama', 'history', 'w...
# 83096  ['action', 'adventure', 'drama', 'history', 'w...
#
# [83097 rows x 7 columns]

# %%
speakers_df_cleaned = speakers_df_cleaned.rename(columns={
    '_key':'Character ID',
    'meta/character_name':'Character Name',
    'meta/movie_idx':'Movie ID',
    'meta/movie_name':'Movie Name',
    'meta/gender':'Gender',
    'meta/credit_pos':'Credit Position'
})
speakers_df_cleaned.head()
# Out:
#   Character ID Character Name Movie ID                  Movie Name Gender  \
# 0           u0         BIANCA       m0  10 things i hate about you      f
# 1           u2        CAMERON       m0  10 things i hate about you      m
# 3           u4           JOEY       m0  10 things i hate about you      m
# 4           u5            KAT       m0  10 things i hate about you      f
# 5          u11         WALTER       m0  10 things i hate about you      m
#
#   Credit Position
# 0               4
# 1               3
# 3               6
# 4               2
# 5               9

# %%
conversations_df = conversations_df.rename(columns={
    '_key':'Conversation ID',
    'meta/movie_idx':'Movie ID',
    'meta/movie_name':'Movie Name',
    'meta/release_year':'Release YEar',
    'meta/rating':'Rating',
    'meta/votes':'IMBD Votes',
    'meta/genre':'Genre'
})
conversations_df.head()
# Out:
#   Conversation ID Movie ID                  Movie Name Release YEar  Rating  \
# 0           L1044       m0  10 things i hate about you         1999     6.9
# 1            L984       m0  10 things i hate about you         1999     6.9
# 2            L924       m0  10 things i hate about you         1999     6.9
# 3            L870       m0  10 things i hate about you         1999     6.9
# 4            L866       m0  10 things i hate about you         1999     6.9
#
#    IMBD Votes                  Genre
# 0       62847  ['comedy', 'romance']
# 1       62847  ['comedy', 'romance']
# 2       62847  ['comedy', 'romance']
# 3       62847  ['comedy', 'romance']
# 4       62847  ['comedy', 'romance']
